# %% [markdown]
# How to connect to MySQL and export data from MySQL to excel | Python | Pandas | Export dataframe
#
# YouTube link: https://youtu.be/mKnMY2GqaGI

# %%
import mysql.connector as connection
import pandas as pd

# %%
sql = "SELECT * FROM classicmodels.orders;"

# %%
# username & password should be same as that of creating a connection in docker container
# & while creating connection in MySQL UI
db = connection.connect(host="localhost", database="classicmodels", user="root", passwd="demopass01", use_pure=True)

# %%
db

# %%
df = pd.read_sql(sql, db)

# %%
df
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104  2003-01-31   2003-02-09  2003-02-01     Shipped
# ..           ...         ...          ...         ...         ...
# 321        10421  2005-05-29   2005-06-06        None  In Process
# 322        10422  2005-05-30   2005-06-11        None  In Process
# 323        10423  2005-05-30   2005-06-05        None  In Process
# 324        10424  2005-05-31   2005-06-08        None  In Process
# 325        10425  2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber
# 0                                                 None             363
# ...

# %%
df.head()
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1        10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2        10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3        10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4        10104  2003-01-31   2003-02-09  2003-02-01  Shipped
#
#                  comments  customerNumber
# 0                    None             363
# 1  Check on availability.             128
# 2                    None             181
# 3                    None             121
# 4                    None             141

# %%
# This will write/save EXCEL at same location as that of *.ipynb file
df.to_excel("mysql_date.xlsx", index=False)

# %%
# We should close the connection which has been opened
db.close()
